# %% [markdown]
# Predicted Emissions (RDU → ORD)
#
# Predicted CO₂ per Distance (kg/km)
#
# | Aircraft Class | Aircraft Type | Predicted CO₂ per Distance (kg/km) |
# |:--------------:|:--------------:|:---------------------------------:|
# | NB             | B738           | 415                               |
# | WB             | B763           | 970                               |
# | RJ             | CRJ2           | 410                               |
# | TP             | C208           | 1030                              |
# | PP             | C172           | 200                               |
# | PJ             | GL5T           | 5                                 |
#
# ---
#
# Predicted CO₂ per Passenger per km (kg/passenger/km)
#
# | Aircraft Class | Aircraft Type | Predicted CO₂ per Passenger per km (kg/passenger/km) |
# |:--------------:|:--------------:|:---------------------------------------------------:|
# | NB             | B738           | 3.1                                                 |
# | WB             | B763           | 5.3                                                 |
# | RJ             | CRJ2           | 10.0                                                |
# | TP             | C208           | 139.0                                               |
# | PP             | C172           | 61.0                                                |
# | PJ             | GL5T           | 0.4                                                 |
#
# ---
# - Assumed Load Factor: **82.4%** (fixed for all aircraft)
# - Passenger count estimated as: **(Typical Seats) × (Load Factor 0.824)**
# - Predictions made with a **Random Forest Regression model**.
