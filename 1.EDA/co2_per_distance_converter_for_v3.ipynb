# %%
import pandas as pd

# %%
data = pd.read_parquet("https://github.com/monatagelsir7/enivornmental_impact_of_aviation/raw/refs/heads/main/cleaned_aviation_data_v2.parquet")
data["co2_per_distance"] = data["co2"] / data["distance_km"]

# %%
numeric_cols = [
    "seats",
    "n_flights",
    "seats_no_est_scaling",
    "distance_km",
    "log_distance",
    "ask",
    "rpk",
    "fuel_burn_seymour",
    "fuel_burn",
    "co2",
    "log_co2",
    "co2_per_distance",
]

# %%
data[numeric_cols].corr()
# Out:
#                          seats  n_flights  seats_no_est_scaling  distance_km  \
# seats                 1.000000   0.296032              0.811385     0.019694
# n_flights             0.296032   1.000000              0.442167    -0.027546
# seats_no_est_scaling  0.811385   0.442167              1.000000     0.049268
# distance_km           0.019694  -0.027546              0.049268     1.000000
# log_distance          0.034548  -0.023746              0.059736     0.792701
# ask                   0.678049   0.215993              0.665127     0.301071
# rpk                   0.678049   0.215993              0.665127     0.301071
# fuel_burn_seymour     0.021046   0.007025              0.045489     0.815369
# fuel_burn             0.698937   0.226136              0.670583     0.293557
# co2                   0.698937   0.226136              0.670583     0.293557
# log_co2               0.379187   0.399100              0.425068     0.360100
# co2_per_distance      0.956887   0.308824              0.757796    -0.013171
#
#                       log_distance       ask       rpk  fuel_burn_seymour  \
# seats                     0.034548  0.678049  0.678049           0.021046
# n_flights                -0.023746  0.215993  0.215993           0.007025
# seats_no_est_scaling      0.059736  0.665127  0.665127           0.045489
# distance_km               0.792701  0.301071  0.301071           0.815369
# log_distance              1.000000  0.212304  0.212304           0.544772
# ask                       0.212304  1.000000  1.000000           0.268028
# rpk                       0.212304  1.000000  1.000000           0.268028
# fuel_burn_seymour         0.544772  0.268028  0.268028           1.000000
# fuel_burn                 0.197251  0.989827  0.989827           0.282195
# co2                       0.197251  0.989827  0.989827           0.282195
# log_co2                   0.465387  0.406016  0.406016           0.297507
# co2_per_distance         -0.018802  0.567361  0.567361           0.007762
#
#                       fuel_burn       co2   log_co2  co2_per_distance
# seats                  0.698937  0.698937  0.379187          0.956887
# n_flights              0.226136  0.226136  0.399100          0.308824
# seats_no_est_scaling   0.670583  0.670583  0.425068          0.757796
# distance_km            0.293557  0.293557  0.360100         -0.013171
# log_distance           0.197251  0.197251  0.465387         -0.018802
# ask                    0.989827  0.989827  0.406016          0.567361
# rpk                    0.989827  0.989827  0.406016          0.567361
# fuel_burn_seymour      0.282195  0.282195  0.297507          0.007762
# fuel_burn              1.000000  1.000000  0.402419          0.607295
# co2                    1.000000  1.000000  0.402419          0.607295
# log_co2                0.402419  0.402419  1.000000          0.347742
# co2_per_distance       0.607295  0.607295  0.347742          1.000000

# %%
data.to_parquet("https://github.com/monatagelsir7/enivornmental_impact_of_aviation/raw/refs/heads/main/cleaned_aviation_data_v3.parquet", index=False)
